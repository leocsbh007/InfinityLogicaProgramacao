# %% [markdown]
# Integrantes:
# 1 - Henrique de Oliveira - lagehenrique05@gmail.com
# 2 - Thomas Lopes - thomcunhapersonal@gmail.com
# 3 - Leonardo Souza - leonardo.castrodesouza@gmail.com

# %% [markdown]
# Exercício 02
#
# O Imposto Nacional Sobre Lucros Expressivos (INLE) é um imposto que incide sobre lucros superiores a R$ 50.000,00, seguindo as regras abaixo:
#
# Lucros entre R 50.000,00eR  75.000,00 têm um imposto de 10%;
#
# Lucros entre R 75.000,00eR  100.000,00 têm um imposto de 15%;
#
# Lucros acima de R$ 100.000,00 têm um imposto de 20%.
#
# Desenvolva um algoritmo que:
#
# Verifique se o INLE incidirá sobre o lucro informado pelo usuário;
# Determine o percentual de imposto que incidirá sobre o lucro, caso as regras do INLE se apliquem;
# Calcule a diferença entre o lucro bruto (sem o imposto) e o lucro líquido (com o imposto);
# Apresente a representação em dinheiro (R$) do percentual do imposto.
# Atenção: desenvolva a atividade na célula de código abaixo.

# %%
lucro_bruto = 101000.00

faixa1 = 50000.0
faixa2 = 75000.0
faixa3 = 100000.0
if lucro_bruto >= faixa1:
  desconto_lucro = 0.0
  percentual_lucro = 0.0
  lucro_liquido = 0.0
  if lucro_bruto >= faixa1 and lucro_bruto <= faixa2:
    percentual_lucro = 10.0
    desconto_lucro = (lucro_bruto * percentual_lucro) / 100
    lucro_liquido = lucro_bruto - desconto_lucro

  if lucro_bruto > faixa2 and lucro_bruto < faixa3:
    percentual_lucro = 15.0
    desconto_lucro = (lucro_bruto * percentual_lucro) / 100
    lucro_liquido = lucro_bruto - desconto_lucro

  if lucro_bruto > faixa3:
      percentual_lucro = 20.0
      desconto_lucro = lucro_bruto * percentual_lucro
      lucro_liquido = (lucro_bruto - desconto_lucro) / 100

  print('Haverá insidencia de INLE...')
  print('Percentual de imposto {}%'.format(percentual_lucro))
  print('Desconto aplicado R${}'.format(lucro_bruto - lucro_liquido))
else:
  print('NÃO haverá insidencia de INLE...')
# Out:
# Haverá insidencia de INLE...
# Percentual de imposto 20.0%
# Desconto aplicado R$120190.0

# %% [markdown]
# Exercício 03
#
# O Programa de Bonificações por Produtividade (PBP) oferece bonificações de acordo com a produtividade mensal de um funcionário, seguindo as regras abaixo:
#
# Produtividade abaixo de 50 unidades: não há bonificação;
#
# Produtividade entre 50 e 100 unidades: bonificação de R$ 100,00;
#
# Produtividade acima de 100 unidades: bonificação de R$ 200,00.
#
# Crie um algoritmo que:
#
# Solicite a produtividade mensal do funcionário;
# Verifique se o funcionário tem direito a bonificação, de acordo com as regras do PBP;
# Exiba a bonificação a que o funcionário tem direito.
# Atenção: desenvolva a atividade na célula de código abaixo.

# %%
produtividade = 100

if produtividade >= 50:
  bonificacao = 0.0

  if produtividade >= 50 and produtividade <=100:
    bonificacao = 100

  if produtividade > 100:
    bonificacao = 200
  print("Haverá bonificação:")
  print(f"Valor da bonificação:R${bonificacao}")
else:
  print("Não haverá bonificação...")
# Out:
# Haverá bonificação:
# Valor da bonificação:R$100

# %% [markdown]
# Exercício 04
#
# A Empresa de Energia Econômica (EEE) cobra a conta de energia elétrica dos consumidores de acordo com a seguinte tabela:
#
# Consumo até 100 kWh: R$ 0,50 por kWh consumido;
#
# Consumo entre 101 kWh e 200 kWh: R$ 0,75 por kWh consumido;
#
# Consumo acima de 200 kWh: R$ 1,00 por kWh consumido.
#
# Crie um programa que:
#
# Solicite ao usuário o consumo mensal de energia em kWh;
#
# Calcule o valor total da conta de acordo com a tabela da EEE.
# Atenção: desenvolva a atividade na célula de código abaixo.

# %%
print('Script para calular o consumo de energia Eletrica')
print(25*'=-')
print(5*'=-','Empresa de Energia Econômica',5*'=-')
print(25*'=-','\n')


consumo_mensal = int(input('Entre com o consumo em kWh: '))
if consumo_mensal < 100:
  conta_energia = consumo_mensal * 0.50
elif consumo_mensal >= 100  and consumo_mensal <= 200:
  conta_energia = consumo_mensal * 0.75
else:
  conta_energia = consumo_mensal * 1.00

print('Seu consumo é de R$', conta_energia)
# Out:
# Script para calular o consumo de energia Eletrica
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-
# =-=-=-=-=- Empresa de Energia Econômica =-=-=-=-=-
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-
#
# Entre com o consumo em kWh: 201
# Seu consumo é de R$ 201.0

# %% [markdown]
# Exercício 05
#
# Desenvolva um programa que simule um caixa eletrônico, permitindo que o usuário faça saques.
#
# O caixa possui notas de R 100,00, R 50,00, R 20,00e R  10,00.
# O algoritmo deve:
#
# Solicitar o valor a ser sacado;
#
# Calcular e informar a quantidade de cada nota necessária para compor o valor total do saque;
#
# Garantir que o valor seja sacado utilizando a menor quantidade possível de notas.
#
# Atenção: desenvolva a atividade na célula de código abaixo.

# %%
num1 = 150
num2 = 10
print(num1/num2)
print(num1%num2)
print(num1//num2)
# Out:
# 15.0
# 0
# 15

# %%
print('Script para Caixa Eletronico')
print(26*'=-')
print(8*'=-','Banco do Leonardo',8*'=-')
print(26*'=-','\n')

print('Notas Disponiveis:')
print('R$100,00 - R$50,00 - R$20,00 - R$10,00\n')
saque = int(input('Por favor entre com o valor a ser Sacado: '))

resto = 0
notas_de_10 = 0
notas_de_20 = 0
notas_de_50 = 0
notas_de_100 = 0

# Verifica se o saque vai ser em multiplo de 10
if (saque%10) != 0:
  print('Só aceita multiplos de 10!!')
else:
  # Valida valores para notas de 10
  if saque >= 10 and saque < 20:
    resto = saque % 10
    notas_de_10 = saque // 10

  # Valida valores para notas de 20
  if saque >= 20 and saque < 50:
    resto = saque % 20
    if resto == 0:
      notas_de_20 = saque // 20
    else:
      notas_de_20 = saque // 20
      notas_de_10 += 1

  # Valida valores para notas de 50
  if saque >= 50 and saque < 100:
    resto = saque % 50
    notas_de_50 = saque // 50
    #Valida para ver se o resto cabe em notas de 20 e notas de 10
    if resto >= 10 and resto < 50:
      # Valida se tera apenas uma nota de 10
      if resto == 10:
        notas_de_10 += 1
      # Valida se tera apenas uma nota de 20
      elif resto == 20:
        notas_de_20 += 1
      # Valida se tera apenas uma nota de 10 e uma nota de 20
      elif resto > 20 and resto <= 30:
        notas_de_20 += 1
        notas_de_10 += 1
      # Valida se tera apenas notas de 20
      else:
        notas_de_20 += 2
  # Valida valores para notas de 100
  if saque >= 100:
    resto = saque % 100
    notas_de_100 = saque // 100
    #Valida para ver se o resto cabe em notas de 50 notas de 20 e notas de 10
    if resto >= 10 and resto < 100:
      # Valida se tera apenas uma nota de 10
      if resto == 10:
        notas_de_10 += 1
      # Valida se tera apenas uma nota de 20
      elif resto == 20:
        notas_de_20 += 1
      # Valida se tera apenas uma nota de 10 e uma nota de 20
      elif resto > 20 and resto <= 30:
        notas_de_20 += 1
        notas_de_10 += 1
      # Valida se tera apenas notas de 20
      elif resto > 30 and resto <= 40:
        notas_de_20 += 2
      # Valida se tera apenas notas de 50
      elif resto > 40 and resto <= 50:
        notas_de_50 += 1
      # Valida se o valor de notas será acima de 50 em menores que notas de 100
      else:
        notas_de_50 += 1
        #Valida para ver se o resto cabe em notas de 20 e notas de 10
        if resto >= 50 and resto < 100:
          # Valida se tera apenas uma nota de 10
          if resto == 60:
            notas_de_10 += 1
          # Valida se tera apenas uma nota de 20
          elif resto == 70:
            notas_de_20 += 1
          # Valida se tera apenas uma nota de 10 e uma nota de 20
          elif resto > 70 and resto <= 80:
            notas_de_20 += 1
            notas_de_10 += 1
          # Valida se tera apenas notas de 20
          else:
            notas_de_20 += 4

  print(f'Serão disponilizadas {notas_de_10} notas de 10, {notas_de_20} notas de 20, {notas_de_50} notas de 50, {notas_de_100} notas de 100')
# Out:
# Script para Caixa Eletronico
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-
# =-=-=-=-=-=-=-=- Banco do Leonardo =-=-=-=-=-=-=-=-
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-
#
# Notas Disponiveis:
# R$100,00 - R$50,00 - R$20,00 - R$10,00
#
# Por favor entre com o valor a ser Sacado: 121
# Só aceita multiplos de 10!!

# %% [markdown]
# Exercício 06
#
# O atendimento eletrônico da Telefônica Guanabara possui um menu eletrônico em que o usuário pode interagir diretamente com o Norberto, a Inteligência Eletrônica da empresa que auxilia os clientes na solução de problemas técnico, pagamentos, upgrade e downgrade de planos etc:
#
# Opção 1 - Compras de Novos Serviços
#
# Opção 2 - Atualização de Dados Cadastrais
#
# Opção 3 - Suporte Técnico
#
# Opção 4 - Contas e Pagamentos
#
# Opção 5 - Liberação de Linha/Internet
#
# Opção 6 - Contratação de Pacotes Adicionais
#
# Opção 7 - Transferência de Titularidade
#
# Opção 8 - Reclamações, Elogios e Sugestões
#
# Opção 9 - Falar com um Especialista
#
# Opção 0 - Sair do Menu Eletrônico
#
# Implemente um algoritmo para o funcionamento do Menu Eletrônico da Telefônica Guanabara.
#
# Atenção: desenvolva a atividade na célula de código abaixo.

# %%
from time import sleep

print('Script para validadação de Menu')
print(25*'=-')
print(7*'=-','Telefônica Guanabara',7*'=-')
print(25*'=-','\n')

print('Seja benvindo a Telefônica Guanabara')
print('Me chamo Norberto e irei te atender')

while True:
  print('Digite uma das opções abaixo para iniciar seu atendimento')
  print('Opção 1 - Compras de Novos Serviços')
  print('Opção 2 - Atualização de Dados Cadastrais')
  print('Opção 3 - Suporte Técnico')
  print('Opção 4 - Contas e Pagamentos')
  print('Opção 5 - Liberação de Linha/Internet')
  print('Opção 6 - Contratação de Pacotes Adicionais')
  print('Opção 7 - Transferência de Titularidade')
  print('Opção 8 - Reclamações, Elogios e Sugestões')
  print('Opção 9 - Falar com um Especialista')
  print('Opção 0 - Sair do Menu Eletrônico')

  opcao = int(input('Escolha sua Opção: '))

  if opcao == 1:
    print('Você escolheu - Compras de Novos Serviços')
    print('Um minuto....')
    sleep(5)
  if opcao == 2:
    print('Você escolheu - Atualização de Dados Cadastrais')
    print('Um minuto....')
    sleep(5)
  if opcao == 3:
    print('Você escolheu - Suporte Técnico')
    print('Um minuto....')
    sleep(5)
  if opcao == 4:
    print('Você escolheu - Contas e Pagamentos')
    print('Um minuto....')
    sleep(5)
  if opcao == 5:
    print('Você escolheu - Liberação de Linha/Internet')
    print('Um minuto....')
    sleep(5)
  if opcao == 6:
    print('Você escolheu - Contratação de Pacotes Adicionais')
    print('Um minuto....')
    sleep(5)
  if opcao == 7:
    print('Você escolheu - Transferência de Titularidade')
    print('Um minuto....')
    sleep(5)
  if opcao == 8:
    print('Você escolheu - Reclamações, Elogios e Sugestões')
    print('Um minuto....')
    sleep(5)
  if opcao == 9:
    print('Você escolheu - Falar com um Especialista')
    print('Um minuto....')
    sleep(5)
  if opcao == 0:
    print('Você escolheu - Sair do Menu Eletrônico')
    print('Obrigado por usar os nossos serviços....')
    sleep(5)
    break
# Out:
# Script para validadação de Menu
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-
# =-=-=-=-=-=-=- Telefônica Guanabara =-=-=-=-=-=-=-
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-
#
# Seja benvindo a Telefônica Guanabara
# Me chamo Norberto e irei te atender
# Digite uma das opções abaixo para iniciar seu atendimento
# Opção 1 - Compras de Novos Serviços
# Opção 2 - Atualização de Dados Cadastrais
# Opção 3 - Suporte Técnico
# Opção 4 - Contas e Pagamentos
# Opção 5 - Liberação de Linha/Internet
# Opção 6 - Contratação de Pacotes Adicionais
# Opção 7 - Transferência de Titularidade
# Opção 8 - Reclamações, Elogios e Sugestões
# Opção 9 - Falar com um Especialista
# Opção 0 - Sair do Menu Eletrônico
# Escolha sua Opção: 5
# Você escolheu - Liberação de Linha/Internet
# Um minuto....
# Digite uma das opções abaixo para iniciar seu atendimento
# Opção 1 - Compras de Novos Serviços
# Opção 2 - Atualização de Dados Cadastrais
# Opção 3 - Suporte Técnico
# ...

# %% [markdown]
# Exercício 07
#
# Imagine um sistema de controle de estoque para uma loja de eletrônicos. Desenvolva um algoritmo que simule as seguintes opções:
#
# Opção 1 - Consultar Estoque
#
# Opção 2 - Adicionar Produto ao Estoque
#
# Opção 3 - Remover Produto do Estoque
#
# Opção 0 - Sair
#
# Implemente um programa que permita ao usuário escolher entre as opções e realizar as ações correspondentes.
#
# Atenção: desenvolva a atividade na célula de código abaixo.

# %%
from time import sleep

print('Script para validadação de Menu')
print(25*'=-')
print(7*'=-','Controle de Estoque',7*'=-')
print(25*'=-','\n')


while True:
  print('Digite uma das opções para acessar o estoque\n')
  print('Opção 1 - Consultar Estoque\n')
  print('Opção 2 - Adicionar Produto ao Estoque\n')
  print('Opção 3 - Remover Produto do Estoque\n')
  print('Opção 0 - Sair\n')
  print(25*'=-')

  opcao = int(input('Escolha sua Opção: '))

  if opcao == 1:
    print('Você escolheu - Consultar Estoque\n')
    codigo = input('Digite o codigo do produto: ')
    sleep(2)
    print(f'Produto XYZ codigo: {codigo}\n')
    sleep(2)
    print(25*'=-','\n')

  if opcao == 2:
    print('Você escolheu - Adicionar Produto ao Estoque\n')
    codigo = input('Digite o codigo do produto: ')
    produto = input('Digite o nome do produto: ')
    sleep(3)
    print(f'Produto {produto}, codigo {codigo} foi cadastrado com sucesso!!!')
    sleep(2)
    print(25*'=-','\n')
  if opcao == 3:
    print('Você escolheu - Remover Produto do Estoque\n')
    codigo = input('Digite o codigo do produto: ')
    sleep(2)
    print(f'Produto Notebook ABC codigo: {codigo}, foi removido da base de dados\n')
    sleep(2)
    print(25*'=-','\n')
  if opcao == 0:
    print('Você escolheu - Sair')
    print('Saindo do Sistema....')
    sleep(1)
    break
# Out:
# Script para validadação de Menu
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-
# =-=-=-=-=-=-=- Controle de Estoque =-=-=-=-=-=-=-
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-
#
# Digite uma das opções para acessar o estoque
#
# Opção 1 - Consultar Estoque
#
# Opção 2 - Adicionar Produto ao Estoque
#
# Opção 3 - Remover Produto do Estoque
#
# Opção 0 - Sair
#
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-
# Escolha sua Opção: 1
# Você escolheu - Consultar Estoque
#
# Digite o codigo do produto: 12345
# Produto XYZ codigo: 12345
#
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-
#
# Digite uma das opções para acessar o estoque
#
# Opção 1 - Consultar Estoque
#
# Opção 2 - Adicionar Produto ao Estoque
#
# Opção 3 - Remover Produto do Estoque
#
# Opção 0 - Sair
#
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-
# Escolha sua Opção: 2
# Você escolheu - Adicionar Produto ao Estoque
#
# Digite o codigo do produto: 2563
# Digite o nome do produto: Bola
# ...

# %% [markdown]
# Exercício 08
#
# Desenvolva um algoritmo para um sistema de pedidos online de uma pizzaria. O menu de opções pode ser algo como:
#
# Opção 1 - Visualizar Menu
#
# Opção 2 - Realizar Pedido
#
# Opção 3 - Consultar Status do Pedido
#
# Opção 0 - Sair
#
# O programa deve permitir que o usuário navegue pelo menu, visualize os itens disponíveis, faça pedidos e consulte o status dos pedidos.
#
# Atenção: desenvolva a atividade na célula de código abaixo.

# %%
from time import sleep
from datetime import datetime
print('Script para Menu de Pizzaria Online')
print(25*'=-')
print(7*'=-','Pizzaria Pinguinho',7*'=-')
print(25*'=-','\n')
pedido = False # Sinaliza que ainda não tem um pedido Ativo
tempo_pedido = 0 # Salva a hora que o peido foi feito
tempo_restante = 0 # Salva o tempo que foi passado desde que o pedido foi feito
tempo_pizza = 0 # Salva a diferença entre o tempo do pedido e o tempo que passou do pedido
duracao_pedido = 25 # Duração minima para os pedidos

while True:
  print('Digite uma das opções para seu Pedido\n')
  print('Opção 1 - Visualizar Menu\n')
  print('Opção 2 - Realizar Pedido\n')
  print('Opção 3 - Consultar Status do Pedido\n')
  print('Opção 0 - Sair\n')
  print(25*'=-')

  opcao = int(input('Escolha sua Opção: '))

  if opcao == 1:
    print('Abaixo as opções de Pizza\n')
    print('3500 - SPACCANAPOLI, R$ 73,00 - Tanto pomodoro, mozzarella de búfala, folhas de basílico, azeite EVO')
    print('3501 - CAGLIARI, R$ 93,00 - Pomodoro, mozzarella especial, alici importado, tomate cereja, orégano, azeite EVO')
    print('3502 - BOLOGNA, R$ 74,00 - Pomodoro, mozzarella especial, legítimo presunto cozido, folhas de basílico, azeite EVO.')
    print('3503 - PALERMO, R$ 89,00 - Pomodoro, alici importado, alcaparras, azeitonas pretas, azeite EVO.')
    print(25*'=-','\n')

  if opcao == 2:
    if pedido == False:
      codigo = int(input('Digite o codigo do seu Pedido: '))
      quantidade = float(input('Quantas pizzas: '))
      if codigo == 3500:
        print(f'Sua Pizza - SPACCANAPOLI, fica pronta em {duracao_pedido} min\n')
        print(f'O valor do seu pedido será de R${quantidade*73.00}')
        print('Obrigado pela escolha')
        pedido = True
        tempo_pedido = datetime.now()
        #print(tempo_pedido)
      elif codigo == 3501:
        print(f'Sua Pizza - CAGLIARI, fica pronta em {duracao_pedido} min\n')
        print(f'O valor do seu pedido será de R${quantidade*93.00}')
        print('Obrigado pela escolha')
        pedido = True
        tempo_pedido = datetime.now()
      elif codigo == 3502:
        print(f'Sua Pizza - BOLOGNA, fica pronta em {duracao_pedido} min\n')
        print(f'O valor do seu pedido será de R${quantidade*74.00}')
        print('Obrigado pela escolha')
        pedido = True
        tempo_pedido = datetime.now()
      elif codigo == 3503:
        print(f'Sua Pizza - PALERMO, fica pronta em {duracao_pedido} min\n')
        print(f'O valor do seu pedido será de R${quantidade*89.00}')
        print('Obrigado pela escolha')
        pedido = True
        tempo_pedido = datetime.now()
      else:
        print('Opção invalida')
    else:
      print('Você já tem um pedido em andamento')
    print(25*'=-','\n')
  if opcao == 3:
    #Atualiza o tempo atual
    tempo_restante = datetime.now()
    #Atualiza o tempo com base no tempo de pedido e tempo atual
    tempo_pizza = tempo_restante - tempo_pedido
    #Valida se o pedido já ficou pronto
    if tempo_pizza.total_seconds() < duracao_pedido:
      print(f'Sua pizza ficara pronta em {tempo_pizza.total_seconds()} min')
    else:
      print('Sua pizza esta pronta.')
      print('Obrigado pela preferência')
      pedido = False
    print(25*'=-','\n')
  if opcao == 0:
    print('Você escolheu - Sair')
    print('Saindo do Sistema....')

    break
# Out:
# Script para Menu de Pizzaria Online
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-
# =-=-=-=-=-=-=- Pizzaria Pinguinho =-=-=-=-=-=-=-
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-
#
# Digite uma das opções para seu Pedido
#
# Opção 1 - Visualizar Menu
#
# Opção 2 - Realizar Pedido
#
# Opção 3 - Consultar Status do Pedido
#
# Opção 0 - Sair
#
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-
# Escolha sua Opção: 2
# Digite o codigo do seu Pedido: 3500
# Quantas pizzas: 1
# Sua Pizza - SPACCANAPOLI, fica pronta em 25 min
#
# O valor do seu pedido será de R$73.0
# Obrigado pela escolha
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-
#
# Digite uma das opções para seu Pedido
#
# Opção 1 - Visualizar Menu
#
# Opção 2 - Realizar Pedido
#
# Opção 3 - Consultar Status do Pedido
#
# Opção 0 - Sair
#
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-
# Escolha sua Opção: 3
# Sua pizza ficara pronta em 4.127308 min
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-
#
# ...

# %% [markdown]
# Exercício 09
#
# Crie um sistema de gerenciamento de tarefas. O menu pode conter opções como:
#
# Opção 1 - Visualizar Lista de Tarefas
#
# Opção 2 - Adicionar Nova Tarefa
#
# Opção 3 - Marcar Tarefa como Concluída
#
# Opção 0 - Sair
#
# Desenvolva um programa que permita ao usuário gerenciar suas tarefas visualizando, adicionando e marcando como concluídas.
#
# Atenção: desenvolva a atividade na célula de código abaixo.

# %%
print('Script para Menu de Controle de Tarefas')
print(25*'=-')
print(7*'=-','Controle de Tarefas',7*'=-')
print(25*'=-','\n')

tarefa1 = 0
feita1 = 0
tarefa2 = 0
feita2 = 0
tarefa3 = 0
feita3 = 0

aguarde = 0
tarefa_temporaria = 0

while True:
  print('O quê vamos Fazer Hoje???\n')
  print('Opção 1 - Visualizar Lista de Tarefas\n')
  print('Opção 2 - Adicionar Nova Tarefa\n')
  print('Opção 3 - Marcar Tarefa como Concluída\n')
  print('Opção 0 - Sair\n')
  print(25*'=-')

  opcao = int(input('Escolha sua Opção: '))

  if opcao == 1:
    print('Visualizando as Tarefas')
    if tarefa1 != 0 and tarefa2 != 0 and tarefa3 != 0:
      print(f'Tarefa - 1 : {tarefa1}')
      print(f'Tarefa - 2 : {tarefa2}')
      print(f'Tarefa - 3 : {tarefa3}')

    elif tarefa1 != 0 and tarefa2 != 0:
      print(f'Tarefa - 1 : {tarefa1}')
      print(f'Tarefa - 2 : {tarefa2}')

    elif tarefa1 != 0 and tarefa3 != 0:
      print(f'Tarefa - 1 : {tarefa1}')
      print(f'Tarefa - 3 : {tarefa3}')

    elif tarefa2 != 0 and tarefa3 != 0:
      print(f'Tarefa - 2 : {tarefa2}')
      print(f'Tarefa - 3 : {tarefa3}')

    elif tarefa1 != 0:
      print(f'Tarefa - 1 : {tarefa1}')

    elif tarefa2 != 0:
      print(f'Tarefa - 2 : {tarefa2}')

    elif tarefa3 != 0:
      print(f'Tarefa - 3 : {tarefa3}')

    else:
      print('Não existem tarefas no Banco')

    aguarde = int(input('Digite 9 para voltar: '))
    while True:
      if aguarde != 9:
        aguarde = int(input('Digite 9 para voltar: '))
      else:
        aguarde = 0
        break

  if opcao == 2:
    if tarefa_temporaria == 0:
      tarefa_temporaria = input('Digite a nova Tarefa: ')

    if tarefa1 == 0:
      tarefa1 = tarefa_temporaria
      tarefa_temporaria = 0
    elif tarefa2 == 0:
      tarefa2 = tarefa_temporaria
      tarefa_temporaria = 0
    elif tarefa3 == 0:
      tarefa3 = tarefa_temporaria
    else:
      print('Infelizmente o banco de Tarefas está cheio!!!')
      print('Marque como concluida para liberar espaço')


  if opcao == 3:
    print('Marcar Tarefa como Concluída')
    if tarefa1 != 0:
      feita1 = int(input(f'Marcar Tarefa - 1 : {tarefa1} como concluida digite 9 '))
      print(25*'=-')
      if feita1 == 9:
        print('Tarefa Concluida com Sucesso ')
        print('Foi retirada do Banco de Tarefas')
        tarefa1 = 0

    if tarefa2 != 0:
      feita2 = int(input(f'Marcar Tarefa - 2 : {tarefa2} como concluida digite 9 '))
      print(25*'=-')
      if feita2 == 9:
        print('Tarefa Concluida com Sucesso ')
        print('Foi retirada do Banco de Tarefas')
        tarefa2 = 0

    if tarefa3 != 0:
      feita3 = int(input(f'Marcar Tarefa - 3 : {tarefa3} como concluida digite 9 '))
      print(25*'=-')
      if feita3 == 9:
        print('Tarefa Concluida com Sucesso ')
        print('Foi retirada do Banco de Tarefas')
        tarefa3 = 0

    if tarefa1 == 0 and tarefa2 == 0 and tarefa3 == 0:
      print('Não existem tarefas no Banco')


  if opcao == 0:
    print('Você escolheu - Sair')
    print('Saindo do Sistema....')
    break
# Out:
# Script para Menu de Controle de Tarefas
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-
# =-=-=-=-=-=-=- Controle de Tarefas =-=-=-=-=-=-=-
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-
#
# O quê vamos Fazer Hoje???
#
# Opção 1 - Visualizar Lista de Tarefas
#
# Opção 2 - Adicionar Nova Tarefa
#
# Opção 3 - Marcar Tarefa como Concluída
#
# Opção 0 - Sair
#
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-
# Escolha sua Opção: 2
# Digite a nova Tarefa: Teste 1
# O quê vamos Fazer Hoje???
#
# Opção 1 - Visualizar Lista de Tarefas
#
# Opção 2 - Adicionar Nova Tarefa
#
# Opção 3 - Marcar Tarefa como Concluída
#
# Opção 0 - Sair
#
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-
# Escolha sua Opção: 3
# Marcar Tarefa como Concluída
# Marcar Tarefa - 1 : Teste 1 como concluida digite 9 1
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-
# O quê vamos Fazer Hoje???
#
# Opção 1 - Visualizar Lista de Tarefas
#
# Opção 2 - Adicionar Nova Tarefa
#
# ...

# %% [markdown]
# Exercício 10
#
# Crie um sistema de rastreamento de encomendas para uma empresa de logística. O menu pode conter opções como:
#
# Opção 1 - Consultar Status da Encomenda
#
# Opção 2 - Atualizar Status da Encomenda
#
# Opção 3 - Adicionar Nova Encomenda
#
# Opção 0 - Sair
#
# O programa deve permitir ao usuário rastrear encomendas, atualizar seus status e adicionar novas encomendas.
#
# Atenção: desenvolva a atividade na célula de código abaixo.

# %%
tipo_int = 0

tipo_float = 0.0

tipo_string = ""

tipo_boleano = True



tipo_int = int(input("Entre com um numero Inteiro: "))

tipo_float = float(input("Entre com um numero real: "))

tipo_string = input("Digite seu nome:" )

tipo_boleano = bool(input("Você tem carteira de motorista? 1 - para sim / 0 - para não: "))



print(type(tipo_int))

print(type(tipo_float))

print(type(tipo_string))

print(type(tipo_boleano))
# Out:
# Entre com um numero Inteiro: 25
# Entre com um numero real: 25.9
# Digite seu nome:Leo
# Você tem carteira de motorista? 1 - para sim / 0 - para não: 0
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
# Escreva um programa em python que pergunte ao usuário a velocidade de um carro.
# Caso ultrapasse 80 km/h, exiba uma mensagem dizendo que o usuário foi multado e
# o valor da multa, cobrando R$20,00 por cada km que exceder 80 km/h.

velocidade = int(input("Qual é a velocidade do Veiculo? "))
if velocidade > 80:
  multa = velocidade * 20.00
  print(f"Você ultrapassou o limite de velocidade, sua multa é de R${multa} por dirigir a  {velocidade} km/h ")
else:
  print("Parabens você esta dirigindo dentro do limite permitido!!")
# Out:
# Qual é a velocidade do Veiculo? 98
# Você ultrapassou o limite de velocidade, sua multa é de R$1960.0 por dirigir a  98 km/h

# %%
condicao1 = True
condicao2 = False

if condicao1 and condicao2:
  print("Codigo_Verdadeiro")
else:
  print("Codigo_Falso")
# Out:
# Codigo_Falso

# %%
numero = 12
if numero % 2 == 0:
  print("Par")
else:
  print("Impar")
# Out:
# Par
