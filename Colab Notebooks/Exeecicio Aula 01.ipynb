# %%
# Exercicio 01

print("Alo mundo")
# Out:
# Alo mundo

# %%
# Exercicio 02

numero = input("Entre com um numero: ")
print("O numero informado foi: ", numero)
# Out:
# Entre com o numero: 19
# O numero informado foi:  19

# %%
# Exercico 03

print("SOMA DE DOIS NUMEROS INTEIROS")
num1 = int(input("Entre com o 1º numero: "))
num2 = int(input("Entre com o 2º numero: "))

print("A soma dos numeros é",num1+num2)
# Out:
# SOMA DE DOIS NUMEROS INTEIROS
# Entre com o 1º numero:10
# Entre com o 2º numero:2
# A soma dos numeros é 12

# %%
# Exercicio 05

print("SUBTRAÇÃO DE DOIS NUMEROS INTEIROS")
num1 = int(input("Entre com o 1º numero: "))
num2 = int(input("Entre com o 2º numero: "))

print("A subtração dos numeros é",num1-num2)
# Out:
# SUBTRAÇÃO DE DOIS NUMEROS
# Entre com o 1º numero:10
# Entre com o 2º numero:132
# A subtração dos numeros é -122

# %%
# Exercicio 06

print("MULTIPLICAÇÃO DE DOIS NUMERO INTEIROS")
num1 = int(input("Entre com o 1º numero: "))
num2 = int(input("Entre com o 2º numero: "))

print("A mutiplicação dos numeros é",num1*num2)
# Out:
# MULTIPLICAÇÃO DE DOIS NUMERO INTEIROS
# Entre com o 1º numero:2
# Entre com o 2º numero:3
# A subtração dos numeros é 6

# %%
# Exercicio 07

print("DIVISÃO DE DOIS NUMERO INTEIROS")
num1 = int(input("Entre com o 1º numero: "))
num2 = int(input("Entre com o 2º numero: "))

print("A divisão dos numeros é","%.2f"%(num1/num2))
# Out:
# DIVISÃO DE DOIS NUMERO INTEIROS
# Entre com o 1º numero:5
# Entre com o 2º numero:3
# A subtração dos numeros é 1.67

# %%
# Exercicio 08

print("MODULO DE DOIS NUMERO INTEIROS (RESTO)")
num1 = int(input("Entre com o 1º numero: "))
num2 = int(input("Entre com o 2º numero: "))

print("O modulo dos numeros é","%.2f"%(num1%num2))
# Out:
# RESTO DIVISÃO DE DOIS NUMERO INTEIROS
# Entre com o 1º numero: 11
# Entre com o 2º numero: 5
# A subtração dos numeros é 1.00

# %%
# Exercicio 10

print("PARTE INTEIRA DE DOIS NUMERO INTEIROS (RESTO)")
num1 = int(input("Entre com o 1º numero: "))
num2 = int(input("Entre com o 2º numero: "))

print("A parte inteira da divisão dos numeros é","%.2f"%(num1//num2))
# Out:
# PARTE INTEIRA DE DOIS NUMERO INTEIROS (RESTO)
# Entre com o 1º numero: 10
# Entre com o 2º numero: 4
# A parte inteira da divisão dos numeros é 2.00

# %%
# Exercicio 11

print("POTENCIA DE DOIS NUMERO INTEIROS (RESTO)")
num1 = int(input("Entre com o 1º numero: "))
num2 = int(input("Entre com o 2º numero: "))

print("A potencia dos numeros é","%.2f"%(num1**num2))
# Out:
# POTENCIA DE DOIS NUMERO INTEIROS (RESTO)
# Entre com o 1º numero: 4
# Entre com o 2º numero: 2
# A potencia dos numeros é 16.00
