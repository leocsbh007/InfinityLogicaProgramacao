# %% [markdown]
# Meu primeiro codigo

# %%
# Isso é um comentário...

# Mostra os caracteres '-=' 15 vezes na tela
print("-="*15)
# Exibindo infomações na tela
print("-=Como programar em Python!!-=")
# Mostra os caracteres '-=' 15 vezes na tela
print("-="*15)
# Out:
# -=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# -=Como programar em Python!!-=
# -=-=-=-=-=-=-=-=-=-=-=-=-=-=-=

# %%
# Exibir a minha Altura
print("Minha altura é: "+str(1.78))
# A virgula separa o valores no print()
print(1,78)
# Usar ponto para exibir numeros do tipo decimal no print()
print(1.78)
print("%.4f" %0.0590) # Formatar quatro casas decimais apos a virgula
# Out:
# Minha altura é: 1.78
# 1 78
# 1.78
# 0.0590

# %%
# Usar o print() para exibir numeros inteiros
print(45) # imprimindo minha idade
# Out:
# 45

# %%
from os import PRIO_PGRP
# Exibir valores boleanos
print(True) # Valor Verdadeiro
print(False)  # Valor Falso
# Out:
# True
# False

# %%
# Escrever no print valores: Texto, decimal, boleano
print("Infomação do Tipo Texto: Texto|", "Informação do Tipo Decimal: ", 1.78,
      "|Informação Bolenana Verdadeira: ", True,
      "|Informação do tipo boleana Falsa: ", False, sep="")
# Out:
# Infomação do Tipo Texto: Texto|Informação do Tipo Decimal: 1.78|Informação Bolenana Verdadeira: True|Informação do tipo boleana Falsa: False

# %% [markdown]
# **Declaração de variaveis**

# %%
# 1ª regra: variáveis devem possuir nomes que fazem sentido
# 2ª regra: não se utiliza caracteres especiais
# 3ª regra: nome é diferente de Nome
# 4ª regra: não se utiliza espaço para criação de variáveis
# 5ª regra: não pode começar com numero
nome = "Leonardo"

# %%
nome = "Leonardo"
idade = 45
casado = True
altura = 1.78

print(nome)
print(idade)
print(casado)
print(altura)
# Out:
# Leonardo
# 45
# True
# 1.78

# %%
print("O meu nome é: ", nome, " |Minha idade é: ", idade, " anos ",
      "|Sou casado: ", casado, " e tenho ", altura, " de altura", sep="")
# Out:
# O meu nome é: Leonardo |Minha idade é: 45 anos |Sou casado: True e tenho 1.78 de altura

# %%
nome = "Isabelle" #<class 'str'>: tipo de dado string
idade = 22        #<class 'int'>: tipo de dade inteiro
altura = 1.73     #<class 'float'>: tipo de dado ponto flutuante
solteira = True   #<class 'bool'>: tipo de dado boleano

print(type(idade)) # type() mostra o tipo da variavel
# Out:
# <class 'int'>
